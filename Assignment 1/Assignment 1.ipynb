# %% [markdown]
# 1. User Login Check

# %%
Default_username = "admin"
Default_password = "1234"

# Taking input from user
username = input("Enter username : ")
password = input("Enter password : ")

# Checking The credentials
if Default_username == username and Default_password == password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username :  admin
# Enter password :  1234
# Login Successful

# %% [markdown]
# 2. Pass / Fail Analyzer

# %%
marks = [45, 78, 90, 33, 60]
#initialising pass students and fail students with zero
pass_students = 0
fail_students = 0

for mark in marks:
    if mark >= 50:
        pass_students += 1
    else:
        fail_students += 1

print("Total number of Students :", len(marks))
print("Number of Students Passed :", pass_students)
print("Number of Students Failed :", fail_students)
# Out:
# Total number of Students : 5
# Number of Students Passed : 3
# Number of Students Failed : 2

# %% [markdown]
# 3. Simple Data Cleaner

# %%
names = [" Alice ", "bob", " CHARLIE "]
#Taking new empty list to add cleaned names
cleaned_names = []

for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)

print("Cleaned Names List:", cleaned_names)
# Out:
# Cleaned Names List: ['alice', 'bob', 'charlie']

# %% [markdown]
# 4. Message Length Analyzer

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for message in messages:
    length = len(message)
    print(f"Message: '{message}', its Length: {length}")
    
    if length > 10:
        print("This message is longer than 10 characters")
# Out:
# Message: 'Hi', its Length: 2
# Message: 'Welcome to the platform', its Length: 23
# This message is longer than 10 characters
# Message: 'OK', its Length: 2

# %% [markdown]
# 5. Error Message Detector

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#initialising error count with zero
error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

print("Total 'ERROR' entries:", error_count)
# Out:
# Total 'ERROR' entries: 2
