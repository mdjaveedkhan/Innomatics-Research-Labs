# %% [markdown]
# # GenAI Prompt Engineering Assignment

# %%
# !pip install -q langchain langchain-core langchain-community langchain-openai python-dotenv

# %%
import os
from dotenv import load_dotenv

load_dotenv()

LLM_AVAILABLE = False

try:
    from langchain_openai import ChatOpenAI
    llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
    LLM_AVAILABLE = True
except Exception as e:
    print("LLM not available, running in template-only mode")
# Out:
# LLM not available, running in template-only mode

# %%
from langchain_core.prompts import PromptTemplate

template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

print(template_1.format(topic="Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %%
template_2 = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

print(template_2.format(topic="Python", audience="kids", tone="fun"))
# Out:
# Explain Python for kids in a fun tone

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful {role}"),
    ("user", "Explain {topic}")
])

messages = chat_template.format_messages(
    role="teacher",
    topic="Neural Networks"
)

for msg in messages:
    print(msg)
# Out:
# content='You are a helpful teacher' additional_kwargs={} response_metadata={}
# content='Explain Neural Networks' additional_kwargs={} response_metadata={}

# %%
def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        audience = "beginner"

    if tone not in valid_tone:
        tone = "formal"

    return audience, tone


print(validate_inputs("kids", "fun"))
# Out:
# ('beginner', 'fun')

# %%
def generate_prompt(topic, audience, tone, style):

    audience, tone = validate_inputs(audience, tone)

    if style == "teaching":
        template = "Explain {topic} for {audience} in a {tone} teaching style"
    elif style == "interview":
        template = "Ask interview questions about {topic} for {audience}"
    elif style == "storytelling":
        template = "Explain {topic} as a story for {audience} in a {tone} tone"
    else:
        return "Invalid style"

    prompt = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=template
    )

    return prompt.format(topic=topic, audience=audience, tone=tone)


print(generate_prompt("AI", "beginner", "fun", "storytelling"))
# Out:
# Explain AI as a story for beginner in a fun tone

# %%
reusable_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

topics = ["AI", "Python", "Data Science", "ML", "Deep Learning"]

for t in topics:
    print(reusable_template.format(topic=t))
# Out:
# Explain AI in simple terms
# Explain Python in simple terms
# Explain Data Science in simple terms
# Explain ML in simple terms
# Explain Deep Learning in simple terms

# %% [raw]
# Architecture Flow:
#
# +-------------+
# | User Input  |
# +-------------+
#        |
#        v
# +-------------+
# |   Prompt    |
# +-------------+
#        |
#        v
# +-------------+
# |     LLM     |
# +-------------+
#        |
#        v
# +-------------+
# |    Chain    |
# +-------------+
#        |
#        v
# +----------------+
# | Tool / Agent   |
# +----------------+
#        |
#        v
# +-------------+
# |   Output    |
# +-------------+

# %% [markdown]
# Key Learnings:
#
# - PromptTemplate enables reusable prompts
# - Multi-input prompts improve flexibility
# - ChatPromptTemplate allows role-based AI
# - Validation ensures robustness
# - Prompt systems are better than hardcoded prompts
#
# This project demonstrates real-world prompt engineering concepts using LangChain.
