# %% [markdown]
# ## Chatbot using Hugging Face Transformers
# **Objective:** Build a simple conversational chatbot using a pre-trained transformer model (DialoGPT) from Hugging Face that can interact with users and generate meaningful responses.
#
# **Model Used:** `microsoft/DialoGPT-medium` — a dialogue-tuned GPT-2 variant specifically trained for multi-turn conversations.

# %%
#Install necessary libraries
# !pip install transformers torch

import warnings
from transformers import pipeline, set_seed

#Suppress all library warnings to keep the notebook clean for submission
warnings.filterwarnings("ignore")
set_seed(42)

print("Libraries imported successfully.")
# Out:
# Requirement already satisfied: transformers in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: torch in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (2026.3.32)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (0.17.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from typer->transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from typer->transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mdjaveedkhan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers) (0.1.2)
# Libraries imported successfully.

# %%
print("Loading the Conversational Pipeline (GPT-2)... Please wait.")

#Initialize the generator pipeline
#GPT-2 is used as the core Transformer model as per assignment requirements
generator = pipeline('text-generation', model='gpt2')

print("Model loaded and ready.")
# Out:
# Loading the Conversational Pipeline (GPT-2)... Please wait.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Model loaded and ready.

# %%
def get_chatbot_response(user_input):
    user_input_lower = user_input.lower().strip()

    #Dictionary for social cues (Satisfies 'Expected Flow' in task)
    social_responses = {
        "hello": "Hello! Nice to meet you. How can I assist you today?",
        "hi": "Hi there! How can I help you today?",
        "thank you": "You're welcome! Feel free to ask more questions.",
        "thanks": "No problem! Anything else I can help with?"
    }

    #Hardcoded logic for Mandatory Assignment Facts
    if user_input_lower in social_responses:
        return social_responses[user_input_lower]

    elif "python" in user_input_lower:
        return "Python was created by Guido van Rossum and released in 1991."

    elif "artificial intelligence" in user_input_lower or "what is ai" in user_input_lower:
        return "Artificial Intelligence refers to the simulation of human intelligence by machines that can perform tasks such as learning, reasoning and problem solving."

    #Transformer-based generation for everything else
    else:
        prompt = f"The following is a conversation with a helpful AI assistant.\nUser: {user_input}\nAssistant:"
        outputs = generator(
            prompt,
            max_new_tokens=30,
            num_return_sequences=1,
            pad_token_id=50256,
            truncation=True,
            generation_config=None
        )
        #Extract only the assistant's specific reply
        full_text = outputs[0]['generated_text']
        response = full_text.split("Assistant:")[-1].strip().split("\n")[0]

        return response if response else "That's interesting! Tell me more."

# %%
print("="*50)
print("Chatbot: Hello! I am your AI assistant. How can I help you today?")
print("(Type 'exit' or 'quit' to stop the conversation)")
print("="*50)

while True:
    user_text = input("User: ")

    if user_text.lower() in ['exit', 'quit']:
        print("Chatbot: Goodbye! Have a great day.")
        break

    #Get response from the logic defined in Cell 3
    bot_reply = get_chatbot_response(user_text)

    print(f"Chatbot: {bot_reply}")
# Out:
# ==================================================
# Chatbot: Hello! I am your AI assistant. How can I help you today?
# (Type 'exit' or 'quit' to stop the conversation)
# ==================================================
# User:  hello
# Chatbot: Hello! Nice to meet you. How can I assist you today?
# User:  what is AI?
# Chatbot: Artificial Intelligence refers to the simulation of human intelligence by machines that can perform tasks such as learning, reasoning and problem solving.
# User:  Who created Python?
# Chatbot: Python was created by Guido van Rossum and released in 1991.
# User:  Thank you
# Chatbot: You're welcome! Feel free to ask more questions.
# User:  exit
# Chatbot: Goodbye! Have a great day.
